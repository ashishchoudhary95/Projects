# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers

# %%
data_train_path = 'Fruits_Vegetables/train'
data_test_path = 'Fruits_Vegetables/test'
data_val_path = 'Fruits_Vegetables/validation'

# %%
img_width = 180
img_height =180

# %%
data_train = tf.keras.utils.image_dataset_from_directory(
    data_train_path,
    shuffle=True,
    image_size=(img_width, img_height),
    batch_size=32,
    validation_split=False)
# Out:
# Found 3115 files belonging to 36 classes.

# %%
data_cat = data_train.class_names

# %%
data_cat
# Out:
# ['apple',
#  'banana',
#  'beetroot',
#  'bell pepper',
#  'cabbage',
#  'capsicum',
#  'carrot',
#  'cauliflower',
#  'chilli pepper',
#  'corn',
#  'cucumber',
#  'eggplant',
#  'garlic',
#  'ginger',
#  'grapes',
#  'jalepeno',
#  'kiwi',
#  'lemon',
#  'lettuce',
#  'mango',
#  'onion',
#  'orange',
#  'paprika',
#  'pear',
#  'peas',
#  'pineapple',
#  'pomegranate',
#  'potato',
#  'raddish',
#  'soy beans',
#  'spinach',
#  'sweetcorn',
#  'sweetpotato',
#  'tomato',
#  'turnip',
#  'watermelon']

# %%
data_val = tf.keras.utils.image_dataset_from_directory(data_val_path,
                                                       image_size=(img_height,img_width),
                                                       batch_size=32,
                                                        shuffle=False,
                                                       validation_split=False)
# Out:
# Found 351 files belonging to 36 classes.

# %%
data_test = tf.keras.utils.image_dataset_from_directory(
data_test_path,
    image_size=(img_height,img_width),
    shuffle=False,
    batch_size=32,
    validation_split=False
)
# Out:
# Found 359 files belonging to 36 classes.

# %%
plt.figure(figsize=(10,10))
for image, labels in data_train.take(1):
    for i in range(9):
        plt.subplot(3,3,i+1)
        plt.imshow(image[i].numpy().astype('uint8'))
        plt.title(data_cat[labels[i]])
        plt.axis('off')

# %%
from tensorflow.keras.models import Sequential

# %%
data_train
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 180, 180, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
model = Sequential([
    layers.Rescaling(1./255),
    layers.Conv2D(16, 3, padding='same', activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(32,3, padding='same',activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(64, 3, padding='same', activation='relu'),
    layers.MaxPooling2D(),
    layers.Flatten(),
    layers.Dropout(0.2),
    layers.Dense(128),
    layers.Dense(len(data_cat))
                  
])

# %%
model.compile(optimizer='adam', loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), metrics=['accuracy'])

# %%
epochs_size = 25
history = model.fit(data_train, validation_data=data_val, epochs=epochs_size)
# Out:
# Epoch 1/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 30s 282ms/step - accuracy: 0.0632 - loss: 3.7065 - val_accuracy: 0.3305 - val_loss: 2.3814
# Epoch 2/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 31s 319ms/step - accuracy: 0.2840 - loss: 2.5160 - val_accuracy: 0.6410 - val_loss: 1.3850
# Epoch 3/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 31s 315ms/step - accuracy: 0.5065 - loss: 1.7278 - val_accuracy: 0.8405 - val_loss: 0.6801
# Epoch 4/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 26s 264ms/step - accuracy: 0.7094 - loss: 0.9937 - val_accuracy: 0.8917 - val_loss: 0.4758
# Epoch 5/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 26s 261ms/step - accuracy: 0.8474 - loss: 0.5534 - val_accuracy: 0.9060 - val_loss: 0.4430
# Epoch 6/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 25s 258ms/step - accuracy: 0.8756 - loss: 0.4104 - val_accuracy: 0.9345 - val_loss: 0.3809
# Epoch 7/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 25s 254ms/step - accuracy: 0.9529 - loss: 0.2336 - val_accuracy: 0.9459 - val_loss: 0.4539
# Epoch 8/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 27s 271ms/step - accuracy: 0.9560 - loss: 0.1992 - val_accuracy: 0.9573 - val_loss: 0.4556
# Epoch 9/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 27s 277ms/step - accuracy: 0.9626 - loss: 0.1690 - val_accuracy: 0.9459 - val_loss: 0.4082
# Epoch 10/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 30s 300ms/step - accuracy: 0.9789 - loss: 0.1323 - val_accuracy: 0.9516 - val_loss: 0.3953
# Epoch 11/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 42s 309ms/step - accuracy: 0.9836 - loss: 0.1116 - val_accuracy: 0.9487 - val_loss: 0.3795
# Epoch 12/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 25s 259ms/step - accuracy: 0.9840 - loss: 0.1161 - val_accuracy: 0.9487 - val_loss: 0.3861
# Epoch 13/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 26s 267ms/step - accuracy: 0.9828 - loss: 0.1090 - val_accuracy: 0.9601 - val_loss: 0.3757
# Epoch 14/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 26s 262ms/step - accuracy: 0.9802 - loss: 0.1254 - val_accuracy: 0.9487 - val_loss: 0.3672
# Epoch 15/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 26s 262ms/step - accuracy: 0.9816 - loss: 0.1218 - val_accuracy: 0.9573 - val_loss: 0.2918
# Epoch 16/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 26s 259ms/step - accuracy: 0.9853 - loss: 0.0665 - val_accuracy: 0.9544 - val_loss: 0.3344
# Epoch 17/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 29s 298ms/step - accuracy: 0.9844 - loss: 0.0968 - val_accuracy: 0.9573 - val_loss: 0.3288
# Epoch 18/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 33s 333ms/step - accuracy: 0.9869 - loss: 0.0811 - val_accuracy: 0.9430 - val_loss: 0.3815
# Epoch 19/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 27s 269ms/step - accuracy: 0.9851 - loss: 0.0564 - val_accuracy: 0.9544 - val_loss: 0.3738
# Epoch 20/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 38s 386ms/step - accuracy: 0.9873 - loss: 0.0810 - val_accuracy: 0.9573 - val_loss: 0.3942
# Epoch 21/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 32s 324ms/step - accuracy: 0.9885 - loss: 0.0705 - val_accuracy: 0.9601 - val_loss: 0.3207
# Epoch 22/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 32s 320ms/step - accuracy: 0.9838 - loss: 0.0701 - val_accuracy: 0.9544 - val_loss: 0.3423
# Epoch 23/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 29s 296ms/step - accuracy: 0.9867 - loss: 0.0697 - val_accuracy: 0.9487 - val_loss: 0.3530
# Epoch 24/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 31s 306ms/step - accuracy: 0.9650 - loss: 0.1319 - val_accuracy: 0.9345 - val_loss: 0.4956
# Epoch 25/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 27s 277ms/step - accuracy: 0.9662 - loss: 0.1369 - val_accuracy: 0.9487 - val_loss: 0.3745

# %%
epochs_range = range(epochs_size)
plt.figure(figsize=(8,8))
plt.subplot(1,2,1)
plt.plot(epochs_range,history.history['accuracy'],label = 'Training Accuracy')
plt.plot(epochs_range, history.history['val_accuracy'],label = 'Validation Accuracy')
plt.title('Accuracy')

plt.subplot(1,2,2)
plt.plot(epochs_range,history.history['loss'],label = 'Training Loss')
plt.plot(epochs_range, history.history['val_loss'],label = 'Validation Loss')
plt.title('Loss')
# Out:
# Text(0.5, 1.0, 'Loss')

# %%
image = 'Apple.jpg'
image = tf.keras.utils.load_img(image, target_size=(img_height,img_width))
img_arr = tf.keras.utils.array_to_img(image)
img_bat=tf.expand_dims(img_arr,0)

# %%
predict = model.predict(img_bat)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step

# %%
score = tf.nn.softmax(predict)

# %%
print('Veg/Fruit in image is {} with accuracy of {:0.2f}'.format(data_cat[np.argmax(score)],np.max(score)*100))
# Out:
# Veg/Fruit in image is apple with accuracy of 99.98

# %%
model.save('Image_classify.keras')
